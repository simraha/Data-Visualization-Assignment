# %% [markdown]
# <br></br>
# <h1><center>Electricity Generation and Capacity throughout provinces in Canada from 2005-2016</center></h1>
# <p><center>Simrah Azfar</center></p>
# <p><center>200291450</center></p>
#
# <h2>Introduction</h2>
#
# <p>The data can be accessed from <a href="https://open.canada.ca/data/en/dataset/2cdf43fc-d4aa-4604-9f21-29777d955810">here</a></p>
#
# <p>I’ve gathered two datasets that consist of an electricity generation dataset and electricity capacity dataset. These datasets include:</p>
# <ul>
#     <li>Region in Canada (province)</li>
#     <li>Source of energy</li>
#     <li>Year</li>
#     <li>Data</li>
#     <li>Unit used to measure the data (GW.h/MW)</li>
# </ul>
# <p>To facilitate a clearer analysis of the dataset, I have opted to exclude Canada as a whole and its territories from the regional breakdown and focus solely on the differences between the individual provinces.</p>
# <p>Electricity generation and electricity capacity are two different but related concepts in the energy sector:
#     <ul>
#     <li>Electricity generation refers to the actual production of electricity by power plants or other facilities. This is sometimes measured in units like gigawatt-hours (GW.h), which represent the amount of electricity produced over a certain period of time</li>
#     <li>Electricity capacity, on the other hand, refers to the maximum amount of electricity that a power plant or facility is capable of producing under ideal conditions. This is usually measured in units like megawatts (MW), which represent the power output of the facility at a given moment</li>
# </ul></p>
# <p>An electricity generation and capacity dataset provides valuable insights into the functioning of the power system and can help inform policy and investment decisions related to energy infrastructure and sustainability as well as energy planning.</p>

# %% [markdown]
# <h2>Motivation</h2>
# <p>The motivation for analyzing this data is to understand the trends and patterns presented. By analyzing the electricity generation and capacity data over time, you can identify trends and patterns in how these metrics have changed in different provinces. This can help you gain insights into factors that may be driving changes in electricity production and consumption, such as changes in population, economic growth, or government policies. After analyzing, you can then predict future trends. This can be helpful for businesses and governmental plans for future needs which can then be identified as potential areas for growth or investments.</p>
# <p>Based on my findings I can make well-educated decisions in the future such as:</p>
# <ol>
#   <li>Total electricity generation</li>
#   <li>Trends over time</li>
#   <li>Regional variations</li>
#     <li>Carbon emissions</li>
#     <li>Electricity Capacity</li>
# </ol>

# %% [markdown]
# <h2>Question</h2>
# <p>How has the mix of electricity generation sources (e.g. coal, natural gas, hydroelectric, wind, solar) varied across different Canadian provinces from 2005 to 2016, and how have these trends changed over time? Based on these trends, what predictions can be made for the mix of electricity generation sources in 2030?</p>

# %% [markdown]
# <h2>Visualization</h2>
# <p>In the graphs below I will be analyzing the data from the datasets</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt

#load the data from CSV file
egd = pd.read_csv('electricity-generation-dataset.csv')

#pivot the data to create a DataFrame with columns for each source
pivot_ecd = egd.pivot_table(index='Year', columns='Source', values='Data')

#plot the data as a line chart with a legend for each source
plot = pivot_ecd.plot(kind='line', figsize=(15, 8))

#set the axis labels and title
plot.set_xlabel('Year')
plot.set_ylabel('Electricity Generation (GW.h)')
plot.set_title('Electricity Generation by Source over Time')
plot.grid()

#display the chart
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

#read in the data
egd = pd.read_csv('electricity-generation-dataset.csv')

#calculate the total electricity generation by region
total_by_region = egd.groupby('Region')['Data'].sum()

#remove following from the total_by_region DataFrame
total_by_region = total_by_region.drop('Canada')
total_by_region = total_by_region.drop('YT')
total_by_region = total_by_region.drop('NT')
total_by_region = total_by_region.drop('NU')

#create the bar chart
total_by_region.plot(kind='bar', figsize=(8,6))

#set the axis labels and title
plt.xlabel('Region (province)')
plt.ylabel('Total Electricity Generation (GW.h)')
plt.title('Total Electricity Generation by Region')
plt.grid()

#display the chart
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

#load the data from CSV file
ecd = pd.read_csv('electricity-capacity-dataset.csv')

#pivot the data to create a DataFrame with columns for each source
pivot_ecd = ecd.pivot_table(index='Year', columns='Source', values='Data')

#plot the data as a line chart with a legend for each source
plot = pivot_ecd.plot(kind='line', figsize=(15, 8))

#set the axis labels and title
plot.set_xlabel('Year')
plot.set_ylabel('Electricity Capacity (MW)')
plot.set_title('Electricity Capacity by Source over Time')
plot.grid()

#display the chart
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

#read in the data
ecd = pd.read_csv('electricity-capacity-dataset.csv')

#calculate the total electricity generation by region
total_by_region = ecd.groupby('Region')['Data'].sum()

#remove Canada from the total_by_region DataFrame
total_by_region = total_by_region.drop('Canada')
total_by_region = total_by_region.drop('YT')
total_by_region = total_by_region.drop('NT')
total_by_region = total_by_region.drop('NU')

#create the bar chart
total_by_region.plot(kind='bar', figsize=(8,6))

#set the axis labels and title
plt.xlabel('Region (province)')
plt.ylabel('Total Electricity Capacity (MW)')
plt.title('Total Electricity Capacity by Region')
plt.grid()

#display the chart
plt.show()

# %% [markdown]
# <h2>Description and Analysis</h2>
# <p>From the previous charts I can make the following assumptions:</p>
# <ul>
#     <li>Quebec has the highest consumption and capacity of electricity out of all the provinces</li>
#     <li>Hydroelectricity is the most generated out of all the power sources, holding the most capacity</li>
#     <li>Price Edward Island had the least consumption and capacity of electricity out of all the provinces</li>
#     <li>Although solar energy capacity grew to be the same as biomass in 2015, it remains the least utilized source of electricity in the analyzed data set</li>
#     <li>In 2011, there was a notable shift in the Canadian electricity generation mix, with coal showing a rapid decline while natural gas saw a significant increase</li>
#     <li>Wind power generation slowly rises after 2010</li>
# </ul>

# %% [markdown]
# <h2>Predictions and Conclusion</h2>
# <p>Looking ahead to the year 2030, I predict that Prince Edward Island will remain the Canadian province with the least consumption and capacity of electricity, given its small population and limited industrial activity. Additionally, Quebec will likely maintain its position as the province with the highest electricity generation and capacity, while hydroelectricity will continue to be the most frequently used energy source across the country.</p>
# <p>In terms of new sources of electricity generation, I anticipate a rise in the use of natural gas as it becomes more affordable and accessible. Additionally, wind power is expected to experience a significant increase, as its capacity continues to grow incrementally. While solar power is slowly increasing in capacity, it is likely that more people will begin to adopt it by 2030.</p>
# <p>Finally, I predict that coal usage will decline significantly in the coming years, given the trend observed between 2009-2016. Overall, these shifts in the Canadian electricity generation mix are likely to be driven by a combination of economic, technological, and environmental factors.</p>
